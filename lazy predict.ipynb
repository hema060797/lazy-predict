# %%
#!pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click==7.1.2 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (7.1.2)
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544 kB)
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp38-cp38-win_amd64.whl (13.0 MB)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
# Requirement already satisfied: PyYAML==5.3.1 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (5.3.1)
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-win_amd64.whl (54.4 MB)
# Requirement already satisfied: six==1.15.0 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: pandas==1.0.5 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (1.0.5)
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: pytest==5.4.3 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: scikit-learn==0.23.1 in c:\users\l\anaconda3\lib\site-packages (from lazypredict) (0.23.1)
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\l\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\l\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2020.1)
# Requirement already satisfied: py>=1.5.0 in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.9.0)
# Requirement already satisfied: packaging in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (8.4.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.4.0)
# Requirement already satisfied: colorama in c:\users\l\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\l\anaconda3\lib\site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\l\anaconda3\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)
# Installing collected packages: numpy, scipy, lightgbm, xgboost, tqdm, joblib, lazypredict
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.5.0
#     Uninstalling scipy-1.5.0:
#       Successfully uninstalled scipy-1.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.47.0
#     Uninstalling tqdm-4.47.0:
#       Successfully uninstalled tqdm-4.47.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.16.0
#     Uninstalling joblib-0.16.0:
#       Successfully uninstalled joblib-0.16.0
# Successfully installed joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 numpy-1.19.1 scipy-1.5.4 tqdm-4.56.0 xgboost-1.1.1

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X = data.data
y= data.target

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# C:\Users\l\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# 100%|██████████| 29/29 [00:02<00:00, 10.59it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.57               0.53     0.53      0.56
#
#                                Time Taken
# Model
# LogisticRegression                   0.06
# SGDClassifier                        0.02
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.03
# RandomForestClassifier               0.35
# ExtraTreesClassifier                 0.25
# RidgeClassifier                      0.03
# QuadraticDiscriminantAnalysis        0.03
# AdaBoostClassifier                   0.34
# KNeighborsClassifier                 0.08
# LinearDiscriminantAnalysis           0.03
# CalibratedClassifierCV               0.06
# LGBMClassifier                       0.19
# XGBClassifier                        0.15
# BernoulliNB                          0.02
# RidgeClassifierCV                    0.03
# PassiveAggressiveClassifier          0.33
# DecisionTreeClassifier               0.03
# LabelPropagation                     0.05
# LabelSpreading                       0.05
# NuSVC                                0.30
# NearestCentroid                      0.02
# BaggingClassifier                    0.10
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.03
# DummyClassifier                      0.03

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.57               0.53     0.53      0.56
#
#                                Time Taken
# Model
# LogisticRegression                   0.06
# SGDClassifier                        0.02
# LinearSVC                            0.02
# Perceptron                           0.02
# SVC                                  0.03
# RandomForestClassifier               0.35
# ExtraTreesClassifier                 0.25
# RidgeClassifier                      0.03
# QuadraticDiscriminantAnalysis        0.03
# AdaBoostClassifier                   0.34
# KNeighborsClassifier                 0.08
# LinearDiscriminantAnalysis           0.03
# CalibratedClassifierCV               0.06
# LGBMClassifier                       0.19
# XGBClassifier                        0.15
# BernoulliNB                          0.02
# RidgeClassifierCV                    0.03
# PassiveAggressiveClassifier          0.33
# DecisionTreeClassifier               0.03
# LabelPropagation                     0.05
# LabelSpreading                       0.05
# NuSVC                                0.30
# NearestCentroid                      0.02
# BaggingClassifier                    0.10
# ExtraTreeClassifier                  0.02
# GaussianNB                           0.03
# DummyClassifier                      0.03

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)


offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:05<00:00,  7.43it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.04
# BaggingRegressor                             0.83       0.88  2.63        0.08
# NuSVR                                        0.82       0.86  2.76        0.02
# RandomForestRegressor                        0.81       0.86  2.79        0.61
# XGBRegressor                                 0.81       0.86  2.79        0.13
# GradientBoostingRegressor                    0.81       0.86  2.84        0.23
# ExtraTreesRegressor                          0.79       0.84  2.98        0.41
# HistGradientBoostingRegressor                0.77       0.83  3.06        1.31
# AdaBoostRegressor                            0.77       0.83  3.06        0.20
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.12
# KNeighborsRegressor                          0.77       0.83  3.12        0.03
# DecisionTreeRegressor                        0.65       0.74  3.79        0.02
# MLPRegressor                                 0.65       0.74  3.80        1.34
# HuberRegressor                               0.64       0.74  3.84        0.06
# GammaRegressor                               0.64       0.73  3.88        0.03
# LinearSVR                                    0.62       0.72  3.96        0.03
# RidgeCV                                      0.62       0.72  3.97        0.03
# BayesianRidge                                0.62       0.72  3.97        0.02
# Ridge                                        0.62       0.72  3.97        0.02
# TransformedTargetRegressor                   0.62       0.72  3.97        0.02
# LinearRegression                             0.62       0.72  3.97        0.02
# ElasticNetCV                                 0.62       0.72  3.98        0.12
# LassoCV                                      0.62       0.72  3.98        0.13
# LassoLarsIC                                  0.62       0.72  3.98        0.02
# LassoLarsCV                                  0.62       0.72  3.98        0.05
# Lars                                         0.61       0.72  3.99        0.02
# LarsCV                                       0.61       0.71  4.02        0.05
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.02
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.02
# ElasticNet                                   0.58       0.69  4.16        0.06
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.10
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.02
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.02
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.02
# ExtraTreeRegressor                           0.08       0.32  6.17        0.03
# DummyRegressor                              -0.38      -0.02  7.56        0.02
# LassoLars                                   -0.38      -0.02  7.56        0.02
# KernelRidge                                -11.50      -8.25 22.74        0.03

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.04
# BaggingRegressor                             0.83       0.88  2.63        0.08
# NuSVR                                        0.82       0.86  2.76        0.02
# RandomForestRegressor                        0.81       0.86  2.79        0.61
# XGBRegressor                                 0.81       0.86  2.79        0.13
# GradientBoostingRegressor                    0.81       0.86  2.84        0.23
# ExtraTreesRegressor                          0.79       0.84  2.98        0.41
# HistGradientBoostingRegressor                0.77       0.83  3.06        1.31
# AdaBoostRegressor                            0.77       0.83  3.06        0.20
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.12
# KNeighborsRegressor                          0.77       0.83  3.12        0.03
# DecisionTreeRegressor                        0.65       0.74  3.79        0.02
# MLPRegressor                                 0.65       0.74  3.80        1.34
# HuberRegressor                               0.64       0.74  3.84        0.06
# GammaRegressor                               0.64       0.73  3.88        0.03
# LinearSVR                                    0.62       0.72  3.96        0.03
# RidgeCV                                      0.62       0.72  3.97        0.03
# BayesianRidge                                0.62       0.72  3.97        0.02
# Ridge                                        0.62       0.72  3.97        0.02
# TransformedTargetRegressor                   0.62       0.72  3.97        0.02
# LinearRegression                             0.62       0.72  3.97        0.02
# ElasticNetCV                                 0.62       0.72  3.98        0.12
# LassoCV                                      0.62       0.72  3.98        0.13
# LassoLarsIC                                  0.62       0.72  3.98        0.02
# LassoLarsCV                                  0.62       0.72  3.98        0.05
# Lars                                         0.61       0.72  3.99        0.02
# LarsCV                                       0.61       0.71  4.02        0.05
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.02
# GeneralizedLinearRegressor                   0.59       0.70  4.12        0.02
# ElasticNet                                   0.58       0.69  4.16        0.06
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.10
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.02
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.02
# GaussianProcessRegressor                     0.23       0.43  5.65        0.05
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.02
# ExtraTreeRegressor                           0.08       0.32  6.17        0.03
# DummyRegressor                              -0.38      -0.02  7.56        0.02
# LassoLars                                   -0.38      -0.02  7.56        0.02
# KernelRidge                                -11.50      -8.25 22.74        0.03

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
X=df.drop('survived',axis=1)
y=df.iloc[:,0]

# %%
X.head()
# Out:
#    pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0       3    male 22.00      1      0  7.25        S  Third    man
# 1       1  female 38.00      1      0 71.28        C  First  woman
# 2       3  female 26.00      0      0  7.92        S  Third  woman
# 3       1  female 35.00      1      0 53.10        S  First  woman
# 4       3    male 35.00      0      0  8.05        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  24%|██▍       | 7/29 [00:00<00:01, 16.84it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  90%|████████▉ | 26/29 [00:01<00:00, 13.55it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 29/29 [00:02<00:00, 13.62it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RidgeClassifier                    1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# BernoulliNB                        1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# NuSVC                              0.99               0.99     0.99      0.99
# KNeighborsClassifier               0.99               0.99     0.99      0.99
# LabelSpreading                     0.98               0.98     0.98      0.98
# LabelPropagation                   0.98               0.98     0.98      0.98
# NearestCentroid                    0.92               0.91     0.91      0.92
# LinearDiscriminantAnalysis         0.84               0.82     0.82      0.84
# DummyClassifier                    0.55               0.52     0.52      0.55
# QuadraticDiscriminantAnalysis      0.62               0.50     0.50      0.48
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.05
# BaggingClassifier                    0.06
# XGBClassifier                        0.10
# SVC                                  0.05
# SGDClassifier                        0.03
# RidgeClassifierCV                    0.06
# RidgeClassifier                      0.03
# RandomForestClassifier               0.32
# Perceptron                           0.03
# PassiveAggressiveClassifier          0.05
# LogisticRegression                   0.06
# LinearSVC                            0.08
# GaussianNB                           0.04
# ExtraTreesClassifier                 0.25
# ExtraTreeClassifier                  0.04
# DecisionTreeClassifier               0.04
# CalibratedClassifierCV               0.16
# BernoulliNB                          0.05
# LGBMClassifier                       0.12
# NuSVC                                0.07
# KNeighborsClassifier                 0.06
# LabelSpreading                       0.10
# LabelPropagation                     0.06
# NearestCentroid                      0.04
# LinearDiscriminantAnalysis           0.04
# DummyClassifier                      0.04
# QuadraticDiscriminantAnalysis        0.03

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RidgeClassifier                    1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# BernoulliNB                        1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# NuSVC                              0.99               0.99     0.99      0.99
# KNeighborsClassifier               0.99               0.99     0.99      0.99
# LabelSpreading                     0.98               0.98     0.98      0.98
# LabelPropagation                   0.98               0.98     0.98      0.98
# NearestCentroid                    0.92               0.91     0.91      0.92
# LinearDiscriminantAnalysis         0.84               0.82     0.82      0.84
# DummyClassifier                    0.55               0.52     0.52      0.55
# QuadraticDiscriminantAnalysis      0.62               0.50     0.50      0.48
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.05
# BaggingClassifier                    0.06
# XGBClassifier                        0.10
# SVC                                  0.05
# SGDClassifier                        0.03
# RidgeClassifierCV                    0.06
# RidgeClassifier                      0.03
# RandomForestClassifier               0.32
# Perceptron                           0.03
# PassiveAggressiveClassifier          0.05
# LogisticRegression                   0.06
# LinearSVC                            0.08
# GaussianNB                           0.04
# ExtraTreesClassifier                 0.25
# ExtraTreeClassifier                  0.04
# DecisionTreeClassifier               0.04
# CalibratedClassifierCV               0.16
# BernoulliNB                          0.05
# LGBMClassifier                       0.12
# NuSVC                                0.07
# KNeighborsClassifier                 0.06
# LabelSpreading                       0.10
# LabelPropagation                     0.06
# NearestCentroid                      0.04
# LinearDiscriminantAnalysis           0.04
# DummyClassifier                      0.04
# QuadraticDiscriminantAnalysis        0.03
